# %%
from utils import *
import pandas as pd
from mlfinlab.data_structures import get_time_bars, get_volume_bars, get_tick_bars, get_dollar_bars
# Out:
# /home/valencia/.pyenv/versions/mlfinlab-env/lib/python3.8/site-packages/mlfinlab/util/fast_ewma.py:14: NumbaDeprecationWarning: The keyword argument 'nopython=False' was supplied. From Numba 0.59.0 the default is being changed to True and use of 'nopython=False' will raise a warning as the argument will have no effect. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit((float64[:], int64), nopython=False, nogil=True)
# /home/valencia/.pyenv/versions/mlfinlab-env/lib/python3.8/site-packages/mlfinlab/networks/dash_graph.py:14: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# /home/valencia/.pyenv/versions/mlfinlab-env/lib/python3.8/site-packages/mlfinlab/networks/dash_graph.py:16: UserWarning:
# ...

# %%
df = load_data()
print(df)
# Out:
#                  date_time   price  volume
# 0      2000-01-03 08:30:34  1496.4       0
# 1      2000-01-03 08:30:36  1496.0       0
# 2      2000-01-03 08:30:37  1495.5       0
# 3      2000-01-03 08:30:46  1495.0       0
# 4      2000-01-03 08:30:53  1495.5       0
# ...                    ...     ...     ...
# 437202 2000-06-30 15:04:14  1469.0       0
# 437203 2000-06-30 15:04:15  1469.5       0
# 437204 2000-06-30 15:04:18  1470.0       0
# 437205 2000-06-30 15:04:29  1470.5       0
# 437206 2000-06-30 15:04:36  1470.0       0
#
# [437207 rows x 3 columns]

# %%
tick_bars = get_tick_bars(df, threshold=200)        # 每200笔成交生成1个tick bar
volume_bars = get_volume_bars(df, threshold=1000)  # 每1000合约生成1个volume bar
dollar_bars = get_dollar_bars(df, threshold=1e6)   # 每100万美元成交生成1个dollar bar

# %%
print(tick_bars)
print(volume_bars)
print(dollar_bars)
# Out:
# None
# None
# None
